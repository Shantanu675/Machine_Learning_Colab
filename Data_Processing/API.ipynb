# %% [markdown]
# <a href="https://colab.research.google.com/github/Shantanu675/Machine_Learning_Colab/blob/main/API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# API - Application Programming Interface

# %%
# installing kaggle library
# !pip install kaggle

# %% [markdown]
# 1. Go to kaggle
# 2. search dataset whose api you want
# 3. create kaggle.json with accepting competition rules
# 4. phone verification
# 5. Upload your kaggle.json file
# 6. Configure path of kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# # Import Earthquake dataset
# api to fetch dataset from kaggle by copy paste command

# %%
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# ...
#  99% 2.26G/2.27G [00:41<00:00, 82.3MB/s]
# 100% 2.27G/2.27G [00:41<00:00, 59.2MB/s]

# %% [markdown]
# Check file installed or not

# %%
# !ls -lh
# Out:
# total 2.3G
# -rw-r--r-- 1 root root   69 Jan  9 19:16 kaggle.json
# -rw-r--r-- 1 root root 2.3G Dec 18  2019 LANL-Earthquake-Prediction.zip
# drwxr-xr-x 1 root root 4.0K Dec 11 14:34 sample_data

# %% [markdown]
# unzip it

# %%
# !unzip -q LANL-Earthquake-Prediction.zip

# %%
# !ls -lh
# Out:
# total 12G
# -rw-r--r-- 1 root root   69 Jan  9 19:16 kaggle.json
# -rw-r--r-- 1 root root 2.3G Dec 18  2019 LANL-Earthquake-Prediction.zip
# drwxr-xr-x 1 root root 4.0K Dec 11 14:34 sample_data
# -rw-r--r-- 1 root root  34K Dec 18  2019 sample_submission.csv
# drwxr-xr-x 2 root root  88K Jan  9 19:43 test
# -rw-r--r-- 1 root root 8.9G Dec 18  2019 train.csv

# %% [markdown]
# now you will have your data load or read it and play with data

# %%
import pandas as pd

pd.read_csv("train.csv", nrows=5)
# Out:
#    acoustic_data  time_to_failure
# 0             12           1.4691
# 1              6           1.4691
# 2              8           1.4691
# 3              5           1.4691
# 4              8           1.4691
