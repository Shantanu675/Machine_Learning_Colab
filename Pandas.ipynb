# %% [markdown]
# <a href="https://colab.research.google.com/github/Shantanu675/Python/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing pandas library
import pandas as pd

# %%
# importing the boston house price data
from sklearn.datasets import load_diabetes

# %%
diabetes_dataset = load_diabetes()

# %%
type(diabetes_dataset)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(diabetes_dataset)
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]]), 'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
# pandas DataFrame
diabetes_df = pd.DataFrame(diabetes_dataset.data, columns = diabetes_dataset.feature_names)

# %%
print(type(diabetes_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
diabetes_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
diabetes_df.shape
# Out:
# (442, 10)

# %%
# importing the data from a CSV file to a pandas DataFrame
# csv file to pandas df
import pandas as pd
cars_df = pd.read_csv('/content/cars.csv', encoding='ISO-8859-1')

# %%
cars_df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
type(cars_df)
# Out:
# pandas.core.frame.DataFrame

# %%
cars_df.shape
# Out:
# (301, 9)

# %% [markdown]
# Loading the data from a excel file to a Pandas DataFrame
# pd.read_excel("file-path")

# %% [markdown]
# Exporting a DataFrame to a csv file

# %%
diabetes_df.to_csv('diabetes.csv')

# %%
# Exporting the pandas DataFrame to an excel file
# df.excel("filename")

# creating a DataFrame with random values
import numpy as np

# %%
random_df = pd.DataFrame(np.random.rand(20, 10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.736305  0.896032  0.646366  0.810466  0.902499  0.194957  0.563912
# 1  0.287438  0.853825  0.460188  0.431267  0.331873  0.356926  0.008583
# 2  0.543815  0.909660  0.963089  0.745905  0.097730  0.440759  0.073978
# 3  0.448024  0.932592  0.961395  0.256048  0.881867  0.626907  0.594531
# 4  0.106377  0.777925  0.440257  0.456432  0.022023  0.813541  0.920805
#
#           7         8         9
# 0  0.930107  0.312267  0.624132
# 1  0.890583  0.947284  0.280656
# 2  0.088754  0.672388  0.143743
# 3  0.708366  0.381961  0.250353
# 4  0.155525  0.711426  0.401093

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# Inspecting a DataFrame

# %%
# finding the numbers of row and columns
diabetes_df.shape
# Out:
# (442, 10)

# %%
# first five row in a DataFrame
diabetes_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
# last five rows of DataFarme
diabetes_df.tail()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064

# %%
# information about the DataFrame
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
# finding the number of missing values
diabetes_df.isnull().sum()
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
# cars DataFrame
cars_df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
# counting the values based on the labels
cars_df.value_counts('Year')
# Out:
# Year
# 2015    61
# 2016    50
# 2014    38
# 2017    35
# 2013    33
# 2012    23
# 2011    19
# 2010    15
# 2008     7
# 2009     6
# 2006     4
# 2005     4
# 2003     2
# 2007     2
# 2004     1
# 2018     1
# Name: count, dtype: int64

# %%
# group the values based on the mean
cars_df.groupby('Year').mean(numeric_only=True)
# Out:
#       Selling_Price  Present_Price     Kms_Driven     Owner
# Year
# 2003       1.300000       5.130000   94500.000000  0.000000
# 2004       1.500000      12.350000  135154.000000  0.000000
# 2005       2.487500       9.485000  104294.000000  0.000000
# 2006       1.437500       9.057500   87422.250000  0.750000
# 2007       0.160000       0.665000   51000.000000  0.500000
# 2008       1.002857       4.759571  112128.571429  0.142857
# 2009       2.816667      10.601667   67820.500000  0.000000
# 2010       5.262667      14.330667   60014.066667  0.066667
# 2011       2.375263       5.148053   40327.368421  0.052632
# 2012       3.841304       7.984783   43798.217391  0.043478
# 2013       3.540909       6.821121   41534.333333  0.030303
# 2014       4.762105       7.837974   38080.315789  0.052632
# 2015       5.927049       8.181967   32109.196721  0.016393
# 2016       5.213200       6.550800   18387.340000  0.020000
# 2017       6.209143       7.008571   10419.800000  0.000000
# ...

# %% [markdown]
# Statistical Measures

# %%
# count or number of values
diabetes_df.count()
# Out:
# age    442
# sex    442
# bmi    442
# bp     442
# s1     442
# s2     442
# s3     442
# s4     442
# s5     442
# s6     442
# dtype: int64

# %%
cars_df.count()
# Out:
# Car_Name         301
# Year             301
# Selling_Price    301
# Present_Price    301
# Kms_Driven       301
# Fuel_Type        301
# Seller_Type      301
# Transmission     301
# Owner            301
# dtype: int64

# %%
# mean value column wise
diabetes_df.mean()
# Out:
# age   -1.444295e-18
# sex    2.543215e-18
# bmi   -2.255925e-16
# bp    -4.854086e-17
# s1    -1.428596e-17
# s2     3.898811e-17
# s3    -6.028360e-18
# s4    -1.788100e-17
# s5     9.243486e-17
# s6     1.351770e-17
# dtype: float64

# %%
# cars_df.mean()   --> some columns contains string data so mean only apply on numeric data
cars_df.select_dtypes(include='number')
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner
# 0    2014           3.35           5.59       27000      0
# 1    2013           4.75           9.54       43000      0
# 2    2017           7.25           9.85        6900      0
# 3    2011           2.85           4.15        5200      0
# 4    2014           4.60           6.87       42450      0
# ..    ...            ...            ...         ...    ...
# 296  2016           9.50          11.60       33988      0
# 297  2015           4.00           5.90       60000      0
# 298  2009           3.35          11.00       87934      0
# 299  2017          11.50          12.50        9000      0
# 300  2016           5.30           5.90        5464      0
#
# [301 rows x 5 columns]

# %%
# standars deviation -- columb wise
diabetes_df.std()
# Out:
# age    0.047619
# sex    0.047619
# bmi    0.047619
# bp     0.047619
# s1     0.047619
# s2     0.047619
# s3     0.047619
# s4     0.047619
# s5     0.047619
# s6     0.047619
# dtype: float64

# %%
# provide minimu value in each column
diabetes_df.min()
# Out:
# age   -0.107226
# sex   -0.044642
# bmi   -0.090275
# bp    -0.112399
# s1    -0.126781
# s2    -0.115613
# s3    -0.102307
# s4    -0.076395
# s5    -0.126097
# s6    -0.137767
# dtype: float64

# %%
diabetes_df.max()
# Out:
# age    0.110727
# sex    0.050680
# bmi    0.170555
# bp     0.132044
# s1     0.153914
# s2     0.198788
# s3     0.181179
# s4     0.185234
# s5     0.133597
# s6     0.135612
# dtype: float64

# %%
# all the statistical measures about the dataframe
diabetes_df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# ...

# %% [markdown]
# Manipulating DataFrame

# %%
# adding the column in DataFrame
diabetes_df['chances'] = diabetes_dataset.target

# %%
diabetes_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  chances
# 0 -0.002592  0.019907 -0.017646    151.0
# 1 -0.039493 -0.068332 -0.092204     75.0
# 2 -0.002592  0.002861 -0.025930    141.0
# 3  0.034309  0.022688 -0.009362    206.0
# 4 -0.002592 -0.031988 -0.046641    135.0

# %%
# removing particular row
diabetes_df.drop(index=0, axis=0)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  chances
# ...

# %%
# remove column
diabetes_df.drop(columns='age', axis=1)
# Out:
#           sex       bmi        bp        s1        s2        s3        s4  \
# 0    0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401 -0.002592
# 1   -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412 -0.039493
# 2    0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356 -0.002592
# 3   -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038  0.034309
# 4   -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142 -0.002592
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674 -0.002592
# 438  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674  0.034309
# 439  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993 -0.011080
# 440 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674  0.026560
# 441 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816 -0.039493
#
#            s5        s6  chances
# 0    0.019907 -0.017646    151.0
# ...

# %%
# locating a row using the index value
diabetes_df.iloc[2]
# Out:
# age          0.085299
# sex          0.050680
# bmi          0.044451
# bp          -0.005670
# s1          -0.045599
# s2          -0.034194
# s3          -0.032356
# s4          -0.002592
# s5           0.002861
# s6          -0.025930
# chances    141.000000
# Name: 2, dtype: float64

# %%
""" if want to permanantly remove any row or column then remove it and store
new data in another variable and use it for further study """

# locating a particular column
print(diabetes_df.iloc[:0]) # 1st column
print(diabetes_df.iloc[:1]) # 2nd column
print(diabetes_df.iloc[:2]) # 3rd column
print(diabetes_df.iloc[:-1]) # last column
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, bp, s1, s2, s3, s4, s5, s6, chances]
# Index: []
#         age      sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.05068  0.061696  0.021872 -0.044223 -0.034821 -0.043401
#
#          s4        s5        s6  chances
# 0 -0.002592  0.019907 -0.017646    151.0
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
#
#          s4        s5        s6  chances
# 0 -0.002592  0.019907 -0.017646    151.0
# 1 -0.039493 -0.068332 -0.092204     75.0
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# ...

# %% [markdown]
# Corelation
# 1) Positive Corelation
# 2) Negative Corelation

# %%
diabetes_df.corr()
# Out:
#               age       sex       bmi        bp        s1        s2        s3  \
# age      1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex      0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi      0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp       0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1       0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2       0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3      -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4       0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5       0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6       0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# chances  0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
# ...
